# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
car = pd.read_csv('US_Accidents_June20.csv')#data from wisconson univ
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-58389a8e29fc> in <module>
#       3 import matplotlib.pyplot as plt
#       4 from sklearn.model_selection import train_test_split
# ----> 5 car = pd.read_csv('US_Accidents_June20.csv')#data from wisconson univ
#
# ...

# %%
#pd.set_option('display.max_columns', None)
#car.head()
car

# %%
#car_2017 = car[(car['Start_Time'] > '2017-01-01') & (car['Start_Time'] <= '2017-12-31')]

# %%
#car_2017

# %%
#car_2017.to_csv (r'newdataframe.csv', index = False, header=True)

# %%
#yearcar = pd.read_csv('newdataframe.csv')#data from wisconson univ
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2dc861726fc4> in <module>
# ----> 1 yearcar = pd.read_csv('newdataframe.csv')#data from wisconson univ
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
#yearcar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ff0f81da9c6a> in <module>
# ----> 1 yearcar
#
# NameError: name 'yearcar' is not defined

# %%
car_2019 = car[(car['Start_Time'] > '2019-01-01') & (car['Start_Time'] <= '2019-12-31')]

# %%
car_2019
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 641495    A-641507  MapQuest  406.0         3  2019-12-26 17:09:52
# 641496    A-641508  MapQuest  406.0         3  2019-12-26 17:10:32
# 744777    A-744800  MapQuest  201.0         2  2019-12-25 09:49:34
# 744778    A-744801  MapQuest  201.0         2  2019-12-25 12:52:38
# 744779    A-744802  MapQuest  201.0         2  2019-12-25 20:43:26
# ...            ...       ...    ...       ...                  ...
# 3513612  A-3513776      Bing    NaN         2  2019-08-23 18:03:25
# 3513613  A-3513777      Bing    NaN         2  2019-08-23 19:11:30
# 3513614  A-3513778      Bing    NaN         2  2019-08-23 19:00:21
# 3513615  A-3513779      Bing    NaN         2  2019-08-23 19:00:21
# 3513616  A-3513780      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 641495   2020-01-10 11:00:00  40.884850  -95.800362       NaN        NaN  ...
# ...

# %%
car_2019.to_csv (r'car_2019.csv', index = False, header=True)

# %%
yearcar = pd.read_csv('car_2019.csv')

# %%
yearcar
# Out:
#                ID    Source    TMC  Severity           Start_Time  \
# 0        A-641507  MapQuest  406.0         3  2019-12-26 17:09:52
# 1        A-641508  MapQuest  406.0         3  2019-12-26 17:10:32
# 2        A-744800  MapQuest  201.0         2  2019-12-25 09:49:34
# 3        A-744801  MapQuest  201.0         2  2019-12-25 12:52:38
# 4        A-744802  MapQuest  201.0         2  2019-12-25 20:43:26
# ...           ...       ...    ...       ...                  ...
# 950994  A-3513776      Bing    NaN         2  2019-08-23 18:03:25
# 950995  A-3513777      Bing    NaN         2  2019-08-23 19:11:30
# 950996  A-3513778      Bing    NaN         2  2019-08-23 19:00:21
# 950997  A-3513779      Bing    NaN         2  2019-08-23 19:00:21
# 950998  A-3513780      Bing    NaN         2  2019-08-23 18:52:06
#
#                    End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0       2020-01-10 11:00:00  40.884850  -95.800362       NaN        NaN  ...
# ...
